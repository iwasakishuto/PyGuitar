# %% [markdown]
# # Export ChordBook

# %% [markdown]
# - Music Name : [欲望に満ちた少年団(ONE OK ROCK)](https://www.ufret.jp/song.php?data=5012)
# - KEY: "B" (You can find key using `guitar.utils.find_key_major_scale`)

# %%
from guitar import Guitar

# %% [markdown]
# #### export chord book

# %%
guitar = Guitar(key="B", scale="major", dark_mode=False, name="欲望に満ちた少年団(ONE OK ROCK)-Whole-notes", font_family="Comic Sans MS")
# Out:
# The current font.family is ['Comic Sans MS'].
# /Users/iwasakishuto/Github/PyGuitar/guitar/utils/coloring_utils.py:14: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   rgba = cm.cmap_d.get(theme)(i/LEN_OCTAVES)

# %%
guitar.set_chord(chode="D#", string=5, mode="minor")
guitar.set_chord(chode="G#", string=6, mode="minor")
guitar.set_chord(chode="E",  string=6, mode="major")
guitar.set_chord(chode="B",  string=5, mode="major")
guitar.set_chord(chode="F#", string=6, mode="minor")
guitar.set_chord(chode="C#", string=5, mode="major")
guitar.set_chord(chode="F#", string=6, mode="sus4")
guitar.set_chord(chode="C#", string=5, mode="7th")
guitar.set_chord(chode="D#", string=5, mode="7th")

# %%
guitar.export_chord_book(fmt="pdf", filename="Whole-notes")
# Out:
# /Users/iwasakishuto/Github/PyGuitar/guitar/main.py:239: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s=note, xy=(x, y_val), color=fc, weight='bold', fontsize=25, ha='center', va='center')
