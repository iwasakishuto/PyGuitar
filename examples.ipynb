# %% [markdown]
# # Guitar Chord Generator

# %%
from guitar import Guitar

# %%
guitar = Guitar(key="C", scale="major")

# %% [markdown]
# #### plot guitar layout

# %%
ax = guitar.plot_chord_layout()

# %% [markdown]
# #### plot guitar strings

# %%
ax = guitar.plot_strings()

# %% [markdown]
# ***

# %% [markdown]
# ## Sample Music
#
# - Music Name : [欲望に満ちた少年団(ONE OK ROCK)](https://www.ufret.jp/song.php?data=5012)
# - KEY: "B"

# %%
from guitar import find_key_major_scale

# %%
find_key_major_scale(majors=["B","E","F#"], minors=["G#", 'D#', 'C#'])
# Out:
# {'B': ['B', 'C#', 'D#', 'E', 'F#', 'G#', 'A#']}

# %%
from guitar import Guitar
guitar = Guitar(key="B", scale="major")

# %%
ax = guitar.plot_strings()

# %% [markdown]
# #### plot chord

# %%
ax = guitar.plot_chord(chode="G#", string=6, mode="minor")

# %%
ax = guitar.plot_chord(chode="D#", string=5, mode="minor")

# %%
ax = guitar.plot_chord(chode="E", string=6, mode="major")

# %%
ax = guitar.plot_chord(chode="B", string=5, mode="major")

# %%
ax = guitar.plot_chord(chode="F#", string=6, mode="minor")

# %%
ax = guitar.plot_chord(chode="C#", string=5, mode="major")

# %%
ax = guitar.plot_chord(chode="F#", string=6, mode="sus4")

# %%
ax = guitar.plot_chord(chode="C#", string=5, mode="7th")

# %%
ax = guitar.plot_chord(chode="D#", string=5, mode="7th")

# %% [markdown]
# #### export chord book

# %%
guitar = Guitar(key="B", scale="major", dark_mode=False)

# %%
guitar.set_chord(chode="D#", string=5, mode="minor")
guitar.set_chord(chode="G#", string=6, mode="minor")
guitar.set_chord(chode="E",  string=6, mode="major")
guitar.set_chord(chode="B",  string=5, mode="major")
guitar.set_chord(chode="F#", string=6, mode="minor")
guitar.set_chord(chode="C#", string=5, mode="major")
guitar.set_chord(chode="F#", string=6, mode="sus4")
guitar.set_chord(chode="C#", string=5, mode="7th")
guitar.set_chord(chode="D#", string=5, mode="7th")

# %%
guitar.export_chord_book(fmt="pdf")
