# %% [markdown]
# # Guitar Chord Generator

# %%
from guitar import Guitar

# %%
guitar = Guitar(key="C", scale="major")

# %% [markdown]
# #### plot guitar layout

# %%
fig, ax = guitar._plot_chord_layout()

# %% [markdown]
# #### plot guitar strings

# %%
guitar.plot_strings()

# %% [markdown]
# ***

# %% [markdown]
# ## Sample Music
#
# - Music Name : [欲望に満ちた少年団(ONE OK ROCK)](https://www.ufret.jp/song.php?data=5012)
# - KEY: "D"

# %%
from guitar import Guitar
guitar = Guitar(key="E", scale="major")

# %%
print(guitar.notes)
# Out:
# ['E', 'F#', 'G#', 'A', 'B', 'C#', 'D#']

# %%
guitar.plot_strings()

# %% [markdown]
# #### plot chord

# %%
guitar.plot_chord(chode="G#", string=6, mode="minor")

# %%
guitar.plot_chord(chode="D#", string=5, mode="minor")

# %%
guitar.plot_chord(chode="E", string=6, mode="major")

# %%
guitar.plot_chord(chode="B", string=5, mode="major")

# %%
guitar.plot_chord(chode="F#", string=6, mode="minor")

# %%
guitar.plot_chord(chode="C#", string=5, mode="major")

# %%
guitar.plot_chord(chode="F#", string=6, mode="sus4")

# %%
guitar.plot_chord(chode="C#", string=5, mode="7th")

# %%
guitar.plot_chord(chode="D#", string=5, mode="7th")
