# %%
from guitar import Guitar

# %%
guitar = Guitar(key="C", scale="major")

# %% [markdown]
# #### plot guitar layout

# %%
fig, ax = guitar._plot_chord_layout()

# %% [markdown]
# #### plot guitar strings

# %%
guitar.plot_strings()

# %% [markdown]
# #### plot chord

# %%
guitar.plot_chord(code="C7")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-65523ab15ba1> in <module>
# ----> 1 guitar.plot_chord(code="C7")
#
# ~/Github/guitar/guitar/main.py in plot_chord(self, code, dark_model)
#      87     def plot_chord(self, code, dark_model=False):
#      88         fig, ax = self._plot_chord_layout(dark_model=dark_model)
# ---> 89         raise NotImplementedError("Not Impremented.")
#      90
#      91     def plot_strings(self, dark_model=False, save=False):
#
# NotImplementedError: Not Impremented.
